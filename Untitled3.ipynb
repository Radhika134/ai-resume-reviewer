# %% [markdown]
# <a href="https://colab.research.google.com/github/Radhika134/ai-resume-reviewer/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kagglehub

# %%
import kagglehub

path = kagglehub.dataset_download("abdallahalidev/plantvillage-dataset")
print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 2.04G/2.04G [01:28<00:00, 24.8MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/abdallahalidev/plantvillage-dataset/versions/3

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Path set karo
path = "/root/.cache/kagglehub/datasets/abdallahalidev/plantvillage-dataset/versions/3"

# Saari folders dekho
for folder in os.listdir(path):
    print(folder)
# Out:
# plantvillage dataset

# %%
import os

# Ek level aur andar jao
path = "/root/.cache/kagglehub/datasets/abdallahalidev/plantvillage-dataset/versions/3/plantvillage dataset"

# Ab saari disease folders dikhenge
for folder in os.listdir(path):
    print(folder)
# Out:
# grayscale
# color
# segmented

# %%
import os

# Color folder ke andar jao
path = "/root/.cache/kagglehub/datasets/abdallahalidev/plantvillage-dataset/versions/3/plantvillage dataset/color"

# Ab saari disease classes dikhegi
for folder in os.listdir(path):
    print(folder)
# Out:
# Tomato___healthy
# Tomato___Tomato_mosaic_virus
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot
# Strawberry___Leaf_scorch
# Grape___Esca_(Black_Measles)
# Peach___healthy
# Soybean___healthy
# Tomato___Late_blight
# Peach___Bacterial_spot
# Apple___healthy
# Raspberry___healthy
# Grape___healthy
# Apple___Cedar_apple_rust
# Corn_(maize)___Northern_Leaf_Blight
# Potato___Late_blight
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot)
# Tomato___Target_Spot
# Apple___Black_rot
# Orange___Haunglongbing_(Citrus_greening)
# Corn_(maize)___healthy
# Tomato___Leaf_Mold
# Cherry_(including_sour)___healthy
# Pepper,_bell___Bacterial_spot
# Strawberry___healthy
# Tomato___Septoria_leaf_spot
# Pepper,_bell___healthy
# Tomato___Bacterial_spot
# Squash___Powdery_mildew
# Cherry_(including_sour)___Powdery_mildew
# Grape___Black_rot
# Apple___Apple_scab
# Potato___Early_blight
# Tomato___Tomato_Yellow_Leaf_Curl_Virus
# Potato___healthy
# Blueberry___healthy
# Tomato___Early_blight
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

dataset_path = "/root/.cache/kagglehub/datasets/abdallahalidev/plantvillage-dataset/versions/3/plantvillage dataset/color"

# Ek folder se pehli image lo
sample_folder = os.path.join(dataset_path, "Tomato___healthy")
sample_image = os.path.join(sample_folder, os.listdir(sample_folder)[0])

# Image dikhao
img = mpimg.imread(sample_image)
plt.imshow(img)
plt.title("Tomato - Healthy 🍅")
plt.axis('off')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127813 (\N{TOMATO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
